# %%
# importing modules
import numpy as np
import pandas as pd
import csv
import math
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("df_filtered.csv", low_memory=False)
df = pd.DataFrame(data)
df=df.drop(["Unnamed: 0"], axis=1)
df
# Out:
#         AdiposeExposed  AdiposeNecrosisExposed    area  AtrophieBlanche  \
# 0                 -1.0                     1.0   33.60              1.0
# 1                 -1.0                     1.0   38.00              1.0
# 2                 -1.0                     1.0   40.28              1.0
# 3                 -1.0                     1.0   40.28              1.0
# 4                 -1.0                     1.0   30.00              1.0
# ...                ...                     ...     ...              ...
# 197470             1.0                     1.0  169.00              1.0
# 197471             1.0                     1.0  130.00              1.0
# 197472             1.0                     1.0  110.00              1.0
# 197473             1.0                     1.0  110.00              1.0
# 197474             1.0                     1.0   40.00              1.0
#
#         BrawnyInduration  Callus  color  CompCompression  CompDiet  Crepitus  \
# 0                    1.0     1.0     13                1         0       1.0
# 1                    1.0     1.0     13                1         0       1.0
# 2                    1.0     1.0      2                1         0       1.0
# 3                    1.0     1.0      2                1         0       1.0
# 4                    1.0     1.0      2                1         0       1.0
# ...                  ...     ...    ...              ...       ...       ...
# 197470               1.0     1.0      8                0         0       1.0
# 197471               1.0     1.0      8                0         0       1.0
# 197472               1.0     1.0      8                0         0       1.0
# 197473               1.0     1.0      8                0         0       1.0
# 197474               1.0     1.0      8                0         0       1.0
#
#         ...  PatientIDWoundNumber  DebridementLevel  Method  Bleeding  \
# 0       ...                     0                 0      13         1
# 1       ...                     0                 0      13         1
# 2       ...                     0                 0      13         1
# 3       ...                     0                 0      13         1
# 4       ...                     0                 0      13         1
# ...     ...                   ...               ...     ...       ...
# 197470  ...                 24436                 3       6         1
# 197471  ...                 24436                 3       6         1
# 197472  ...                 24436                 3       6         1
# 197473  ...                 24436                 3       6         1
# 197474  ...                 24436                 3       6         1
#
#         IsThisBurn  SInsuranceZip  PInsuranceZip  Wound_healing_status  \
# 0                1             68             64                     4
# 1                1             68             64                     3
# 2                1             68             64                     3
# 3                1             68             64                     3
# 4                1             68             64                     0
# ...            ...            ...            ...                   ...
# 197470           1             68             43                     3
# 197471           1             68             43                     0
# 197472           1             68             43                     3
# 197473           1             68             43                     3
# 197474           1             68             43                     0
#
#         Wound_healing_percentage  DayNumber
# 0                            NaN          1
# 1                     -13.095238          8
# 2                      -6.000000         15
# 3                       0.000000         22
# 4                      25.521351         29
# ...                          ...        ...
# 197470               -108.641975         72
# 197471                 23.076923         75
# 197472                 15.384615         80
# 197473                  0.000000         87
# 197474                 63.636364         92
#
# [197475 rows x 117 columns]

# %%
# dropping duplicate values 
df = df.drop_duplicates()
df = df.reset_index()
df = df.drop(["index"], axis = 1)
df
# Out:
#         AdiposeExposed  AdiposeNecrosisExposed    area  AtrophieBlanche  \
# 0                 -1.0                     1.0   33.60              1.0
# 1                 -1.0                     1.0   38.00              1.0
# 2                 -1.0                     1.0   40.28              1.0
# 3                 -1.0                     1.0   40.28              1.0
# 4                 -1.0                     1.0   30.00              1.0
# ...                ...                     ...     ...              ...
# 197470             1.0                     1.0  169.00              1.0
# 197471             1.0                     1.0  130.00              1.0
# 197472             1.0                     1.0  110.00              1.0
# 197473             1.0                     1.0  110.00              1.0
# 197474             1.0                     1.0   40.00              1.0
#
#         BrawnyInduration  Callus  color  CompCompression  CompDiet  Crepitus  \
# 0                    1.0     1.0     13                1         0       1.0
# 1                    1.0     1.0     13                1         0       1.0
# 2                    1.0     1.0      2                1         0       1.0
# 3                    1.0     1.0      2                1         0       1.0
# 4                    1.0     1.0      2                1         0       1.0
# ...                  ...     ...    ...              ...       ...       ...
# 197470               1.0     1.0      8                0         0       1.0
# 197471               1.0     1.0      8                0         0       1.0
# 197472               1.0     1.0      8                0         0       1.0
# 197473               1.0     1.0      8                0         0       1.0
# 197474               1.0     1.0      8                0         0       1.0
#
#         ...  PatientIDWoundNumber  DebridementLevel  Method  Bleeding  \
# 0       ...                     0                 0      13         1
# 1       ...                     0                 0      13         1
# 2       ...                     0                 0      13         1
# 3       ...                     0                 0      13         1
# 4       ...                     0                 0      13         1
# ...     ...                   ...               ...     ...       ...
# 197470  ...                 24436                 3       6         1
# 197471  ...                 24436                 3       6         1
# 197472  ...                 24436                 3       6         1
# 197473  ...                 24436                 3       6         1
# 197474  ...                 24436                 3       6         1
#
#         IsThisBurn  SInsuranceZip  PInsuranceZip  Wound_healing_status  \
# 0                1             68             64                     4
# 1                1             68             64                     3
# 2                1             68             64                     3
# 3                1             68             64                     3
# 4                1             68             64                     0
# ...            ...            ...            ...                   ...
# 197470           1             68             43                     3
# 197471           1             68             43                     0
# 197472           1             68             43                     3
# 197473           1             68             43                     3
# 197474           1             68             43                     0
#
#         Wound_healing_percentage  DayNumber
# 0                            NaN          1
# 1                     -13.095238          8
# 2                      -6.000000         15
# 3                       0.000000         22
# 4                      25.521351         29
# ...                          ...        ...
# 197470               -108.641975         72
# 197471                 23.076923         75
# 197472                 15.384615         80
# 197473                  0.000000         87
# 197474                 63.636364         92
#
# [197475 rows x 117 columns]

# %%
df['PatientIDWoundNumber'].nunique()
# Out:
# 24437

# %% [markdown]
# ## Group the dataframe and sort based on the unique wounds sequentially

# %%
big_df=pd.DataFrame()

sorted_df = df.sort_values('PatientIDWoundNumber')
#sorted_df=sorted_df[sorted_df.DateAdded_woundassessment.notnull()]
#sorted_df["area"]=sorted_df["area"].replace(0,0.00001)

unique_wounds=sorted_df["PatientIDWoundNumber"].unique().tolist()
for i in range(len(unique_wounds)):
    print(i)
    
    wound=unique_wounds[i]
    df_wound=sorted_df.query("PatientIDWoundNumber==@wound")
    #df_wound=df_wound[["PatientIDWoundNumber","DateAdded_woundassessment","area"]]
    df_wound=df_wound.drop_duplicates()
    df_wound=df_wound[df_wound.area.notnull()]

    
    # Convert 'DateAdded_woundassessment' column to datetime type
    #df_wound['DateAdded_woundassessment'] = pd.to_datetime(df_wound['DateAdded_woundassessment'])

    # Keep the maximum value in 'area' for each date
    df_wound = df_wound.loc[df_wound.groupby('DayNumber')['area'].idxmax()]

    df_wound=df_wound.sort_values('DayNumber')
    
    big_df = pd.concat([big_df, df_wound], axis=0)

# %%
# Finding the most number of visits across all patients and wounds
grouped_data = big_df.groupby(['PatientIDWoundNumber'])['DayNumber'].count()
maximum = grouped_data.max()

print(grouped_data)
print("MAX:" + str(maximum))
# Out:
# PatientIDWoundNumber
# 0        10
# 1         1
# 2         5
# 3         3
# 4         2
#          ..
# 24432     2
# 24433     2
# 24434     3
# 24435     3
# 24436    23
# Name: DayNumber, Length: 24437, dtype: int64
# MAX:469

# %%
len(big_df.columns)
# Out:
# 117

# %%
df_wound
# Out:
#         AdiposeExposed  AdiposeNecrosisExposed   area  AtrophieBlanche  \
# 197452             1.0                     1.0  234.0              1.0
# 197453             1.0                     1.0  234.0              1.0
# 197454             1.0                     1.0  225.0              1.0
# 197455             1.0                     1.0  225.0              1.0
# 197456             1.0                     1.0  169.0              1.0
# 197457             1.0                     1.0  169.0              1.0
# 197458             1.0                     1.0  180.0              1.0
# 197459             1.0                     1.0  168.0              1.0
# 197460             1.0                     1.0  144.0              1.0
# 197461             1.0                     1.0  144.0              1.0
# 197462             1.0                     1.0  120.0              1.0
# 197463             1.0                     1.0  120.0              1.0
# 197464             1.0                     1.0  130.0              1.0
# 197465             1.0                     1.0  130.0              1.0
# 197466             1.0                     1.0   72.0              1.0
# 197467             1.0                     1.0   72.0              1.0
# 197468             1.0                     1.0   81.0              1.0
# 197469             1.0                     1.0   81.0              1.0
# 197470             1.0                     1.0  169.0              1.0
# 197471             1.0                     1.0  130.0              1.0
# 197472             1.0                     1.0  110.0              1.0
# 197473             1.0                     1.0  110.0              1.0
# 197474             1.0                     1.0   40.0              1.0
#
#         BrawnyInduration  Callus  color  CompCompression  CompDiet  Crepitus  \
# 197452               1.0     1.0      8                0         0       1.0
# 197453               1.0     1.0      8                0         0       1.0
# 197454               1.0     1.0      8                0         0       1.0
# 197455               1.0     1.0      8                0         0       1.0
# 197456               1.0     1.0      8                0         0       1.0
# 197457               1.0     1.0      8                0         0       1.0
# 197458               1.0     1.0      8                0         0       1.0
# 197459               1.0     1.0      8                0         0       1.0
# 197460               1.0     1.0      8                0         0       1.0
# 197461               1.0     1.0      8                0         0       1.0
# 197462               1.0     1.0      8                0         0       1.0
# 197463               1.0     1.0      8                0         0       1.0
# 197464               1.0     1.0      8                0         0       1.0
# 197465               1.0     1.0      8                0         0       1.0
# 197466               1.0     1.0      8                0         0       1.0
# 197467               1.0     1.0      8                0         0       1.0
# 197468               1.0     1.0      8                0         0       1.0
# 197469               1.0     1.0      8                0         0       1.0
# 197470               1.0     1.0      8                0         0       1.0
# 197471               1.0     1.0      8                0         0       1.0
# 197472               1.0     1.0      8                0         0       1.0
# 197473               1.0     1.0      8                0         0       1.0
# 197474               1.0     1.0      8                0         0       1.0
#
#         ...  PatientIDWoundNumber  DebridementLevel  Method  Bleeding  \
# 197452  ...                 24436                 3       6         1
# 197453  ...                 24436                 3       6         1
# 197454  ...                 24436                 3       6         1
# 197455  ...                 24436                 3       6         1
# 197456  ...                 24436                 3       6         1
# 197457  ...                 24436                 3       6         1
# 197458  ...                 24436                 3       6         1
# 197459  ...                 24436                 3       6         1
# 197460  ...                 24436                 3       6         1
# 197461  ...                 24436                 3       6         1
# 197462  ...                 24436                 3       6         1
# 197463  ...                 24436                 3       6         1
# 197464  ...                 24436                 3       6         1
# 197465  ...                 24436                 3       6         1
# 197466  ...                 24436                 3       6         1
# 197467  ...                 24436                 3       6         1
# 197468  ...                 24436                 3       6         1
# 197469  ...                 24436                 3       6         1
# 197470  ...                 24436                 3       6         1
# 197471  ...                 24436                 3       6         1
# 197472  ...                 24436                 3       6         1
# 197473  ...                 24436                 3       6         1
# 197474  ...                 24436                 3       6         1
#
#         IsThisBurn  SInsuranceZip  PInsuranceZip  Wound_healing_status  \
# 197452           1             68             43                     4
# 197453           1             68             43                     3
# 197454           1             68             43                     3
# 197455           1             68             43                     3
# 197456           1             68             43                     0
# 197457           1             68             43                     3
# 197458           1             68             43                     3
# 197459           1             68             43                     3
# 197460           1             68             43                     3
# 197461           1             68             43                     3
# 197462           1             68             43                     3
# 197463           1             68             43                     3
# 197464           1             68             43                     3
# 197465           1             68             43                     3
# 197466           1             68             43                     0
# 197467           1             68             43                     3
# 197468           1             68             43                     3
# 197469           1             68             43                     3
# 197470           1             68             43                     3
# 197471           1             68             43                     0
# 197472           1             68             43                     3
# 197473           1             68             43                     3
# 197474           1             68             43                     0
#
#         Wound_healing_percentage  DayNumber
# 197452                       NaN          1
# 197453                  0.000000          8
# 197454                  3.846154          9
# 197455                  0.000000         12
# 197456                 24.888889         16
# 197457                  0.000000         19
# 197458                 -6.508876         23
# 197459                  6.666667         29
# 197460                 14.285714         36
# 197461                  0.000000         38
# 197462                 16.666667         43
# 197463                  0.000000         45
# 197464                 -8.333333         50
# 197465                  0.000000         53
# 197466                 44.615385         57
# 197467                  0.000000         59
# 197468                -12.500000         64
# 197469                  0.000000         66
# 197470               -108.641975         72
# 197471                 23.076923         75
# 197472                 15.384615         80
# 197473                  0.000000         87
# 197474                 63.636364         92
#
# [23 rows x 117 columns]

# %%
pd.set_option('display.max_rows', 500)

# Count the number of unique values in each column
unique_counts = df_wound.nunique()

# Display the result
unique_counts.head(117)
# Out:
# AdiposeExposed               1
# AdiposeNecrosisExposed       1
# area                        12
# AtrophieBlanche              1
# BrawnyInduration             1
# Callus                       1
# color                        1
# CompCompression              1
# CompDiet                     1
# Crepitus                     1
# Denuded                      1
# Depth                        6
# DryScaly                     1
# Ecchymosis                   1
# Edema                        2
# Erythema                     2
# Excoriation                  1
# ExposedMuscle                1
# ExposedTendon                1
# Exudate                      1
# ExudateAmount                2
# Fluctuance                   1
# Friable                      1
# greygran                     1
# Hemosiderosis                1
# imageFileCount               2
# Induration                   3
# Length                       7
# Maceration                   1
# Moist                        1
# NoMeasurableDepth            1
# NormalColor                  1
# NormalMoisture               1
# normalTexture                1
# Odor                         2
# Pain                         1
# pinkgran                     2
# Rash                         1
# redgran                      1
# Rubor                        1
# Scarring                     1
# Shiny                        1
# sinustract                   1
# slough                       5
# SloughLessThan20             1
# SSCAndSPending               1
# SSConfirmedLocal             2
# SSSignsAndSymptoms           2
# SSSystemicAntibiotics        2
# SSXRay                       1
# Stage                        2
# surroundingSkin              1
# surroundingSkinColor         1
# SystematicInfection          2
# Temperature                  1
# TendonNecrosisExposed        1
# tunneling                    0
# TunnelingOrUndermining       1
# Width                        8
# woundProgress                4
# GranulationTexture           2
# WoundMargin                  2
# eschar                       3
# Woundassessment_Title        1
# Woundassessment_VisitID     23
# AccidentType                 1
# Anterior_Posterior           1
# Anterior_Dorsal              1
# DateAcquired                 1
# DateInactive                 1
# DateOfAccident               1
# DateWoundHealed              1
# Inferior_Superior            1
# Left_Right                   1
# Location                     1
# Notes                        1
# Proximal_Distal              1
# ResolvedRecurrence           1
# ResultOfAccident             1
# Type                         1
# WoundCondition               1
# woundstatus                  1
# DateAdded_wound              1
# AdmissionDate                1
# AdmissionStatusCode          1
# MedicareAdmission            1
# NonWoundDiagnosis            1
# PalliativeCare               1
# StartDate                    1
# CauseOfDeath                 1
# DateOfDeath                  1
# ethnicityCdcCode             1
# PatientDOB                   1
# PatientGender                1
# PatientSelfCare              1
# PatientZIP                   1
# RaceCodeList                 1
# Religion                     1
# DateAdded_patient            1
# Age                         22
# Height                       1
# Weight                       1
# Patient_RiskLevel            1
# Patient_Score                1
# BMI                          1
# SmokingStatus                1
# SmokingStatusText            1
# PatientIDWoundNumber         1
# DebridementLevel             1
# Method                       1
# Bleeding                     1
# IsThisBurn                   1
# SInsuranceZip                1
# PInsuranceZip                1
# Wound_healing_status         3
# Wound_healing_percentage    14
# DayNumber                   23
# dtype: int64

# %%
df_wound.columns.tolist()
# Out:
# ['AdiposeExposed',
#  'AdiposeNecrosisExposed',
#  'area',
#  'AtrophieBlanche',
#  'BrawnyInduration',
#  'Callus',
#  'color',
#  'CompCompression',
#  'CompDiet',
#  'Crepitus',
#  'Denuded',
#  'Depth',
#  'DryScaly',
#  'Ecchymosis',
#  'Edema',
#  'Erythema',
#  'Excoriation',
#  'ExposedMuscle',
#  'ExposedTendon',
#  'Exudate',
#  'ExudateAmount',
#  'Fluctuance',
#  'Friable',
#  'greygran',
#  'Hemosiderosis',
#  'imageFileCount',
#  'Induration',
#  'Length',
#  'Maceration',
#  'Moist',
#  'NoMeasurableDepth',
#  'NormalColor',
#  'NormalMoisture',
#  'normalTexture',
#  'Odor',
#  'Pain',
#  'pinkgran',
#  'Rash',
#  'redgran',
#  'Rubor',
#  'Scarring',
#  'Shiny',
#  'sinustract',
#  'slough',
#  'SloughLessThan20',
#  'SSCAndSPending',
#  'SSConfirmedLocal',
#  'SSSignsAndSymptoms',
#  'SSSystemicAntibiotics',
#  'SSXRay',
#  'Stage',
#  'surroundingSkin',
#  'surroundingSkinColor',
#  'SystematicInfection',
#  'Temperature',
#  'TendonNecrosisExposed',
#  'tunneling',
#  'TunnelingOrUndermining',
#  'Width',
#  'woundProgress',
#  'GranulationTexture',
#  'WoundMargin',
#  'eschar',
#  'Woundassessment_Title',
#  'Woundassessment_VisitID',
#  'AccidentType',
#  'Anterior_Posterior',
#  'Anterior_Dorsal',
#  'DateAcquired',
#  'DateInactive',
#  'DateOfAccident',
#  'DateWoundHealed',
#  'Inferior_Superior',
#  'Left_Right',
#  'Location',
#  'Notes',
#  'Proximal_Distal',
#  'ResolvedRecurrence',
#  'ResultOfAccident',
#  'Type',
#  'WoundCondition',
#  'woundstatus',
#  'DateAdded_wound',
#  'AdmissionDate',
#  'AdmissionStatusCode',
#  'MedicareAdmission',
#  'NonWoundDiagnosis',
#  'PalliativeCare',
#  'StartDate',
#  'CauseOfDeath',
#  'DateOfDeath',
#  'ethnicityCdcCode',
#  'PatientDOB',
#  'PatientGender',
#  'PatientSelfCare',
#  'PatientZIP',
#  'RaceCodeList',
#  'Religion',
#  'DateAdded_patient',
#  'Age',
#  'Height',
#  'Weight',
#  'Patient_RiskLevel',
#  'Patient_Score',
#  'BMI',
#  'SmokingStatus',
#  'SmokingStatusText',
#  'PatientIDWoundNumber',
#  'DebridementLevel',
#  'Method',
#  'Bleeding',
#  'IsThisBurn',
#  'SInsuranceZip',
#  'PInsuranceZip',
#  'Wound_healing_status',
#  'Wound_healing_percentage',
#  'DayNumber']

# %%
df_wound["Age"]=df_wound["Age"].mean()

# %%
#Columns to be transposed
list_to_transpose = ['AdiposeExposed',
 'AdiposeNecrosisExposed',
 'area',
 'AtrophieBlanche',
 'BrawnyInduration',
 'Callus',
 'color',
 'CompCompression',
 'CompDiet',
 'Crepitus',
 'Denuded',
 'Depth',
 'DryScaly',
 'Ecchymosis',
 'Edema',
 'Erythema',
 'Excoriation',
 'ExposedMuscle',
 'ExposedTendon',
 'Exudate',
 'ExudateAmount',
 'Fluctuance',
 'Friable',
 'greygran',
 'Hemosiderosis',
 'imageFileCount',
 'Induration',
 'Length',
 'Maceration',
 'Moist',
 'NoMeasurableDepth',
 'NormalColor',
 'NormalMoisture',
 'normalTexture',
 'Odor',
 'Pain',
 'pinkgran',
 'Rash',
 'redgran',
 'Rubor',
 'Scarring',
 'Shiny',
 'sinustract',
 'slough',
 'SloughLessThan20',
 'SSCAndSPending',
 'SSConfirmedLocal',
 'SSSignsAndSymptoms',
 'SSSystemicAntibiotics',
 'SSXRay',
 'Stage',
 'surroundingSkin',
 'surroundingSkinColor',
 'SystematicInfection',
 'Temperature',
 'TendonNecrosisExposed',
 'tunneling',
 'TunnelingOrUndermining',
 'Width',
 'woundProgress',
 'GranulationTexture',
 'WoundMargin',
 'eschar',
 'Wound_healing_status',
 'Wound_healing_percentage',
 'DayNumber']

# columns not to be transposed
list_not_transpose = ['AccidentType',
 'Anterior_Posterior',
 'Anterior_Dorsal',
 'DateAcquired',
 'DateInactive',
 'DateOfAccident',
 'DateWoundHealed',
 'Inferior_Superior',
 'Left_Right',
 'Location',
 'Notes',
 'Proximal_Distal',
 'ResolvedRecurrence',
 'ResultOfAccident',
 'Type',
 'WoundCondition',
 'woundstatus',
 'DateAdded_wound',
 'AdmissionDate',
 'AdmissionStatusCode',
 'MedicareAdmission',
 'NonWoundDiagnosis',
 'PalliativeCare',
 'StartDate',
 'CauseOfDeath',
 'DateOfDeath',
 'ethnicityCdcCode',
 'PatientDOB',
 'PatientGender',
 'PatientSelfCare',
 'PatientZIP',
 'RaceCodeList',
 'Religion',
 'DateAdded_patient',
 'Age',
 'Height',
 'Weight',
 'Patient_RiskLevel',
 'Patient_Score',
 'BMI',
 'SmokingStatus',
 'SmokingStatusText',
 'PatientIDWoundNumber',
 'DebridementLevel',
 'Method',
 'Bleeding',
 'IsThisBurn',
 'SInsuranceZip',
 'PInsuranceZip']

# %% [markdown]
# ## Atika's..

# %%
transposed_big_df=pd.DataFrame()

list_unique_wound=big_df["PatientIDWoundNumber"].unique().tolist()

# Columns to transpose
# list_to_transpose
# list_not_transpose

for i in range(len(list_unique_wound)):
#     if i>40:
#         break
    print(i)
    unique_wound_number=list_unique_wound[i]
    wound_df=big_df.query("PatientIDWoundNumber== @unique_wound_number")
    #display(wound_df)
    
    df=wound_df
    # Transpose selected columns
    transposed_df = pd.concat([df[list_to_transpose].shift(-i).add_suffix(f'_Visit{i+1}') for i in range(len(df))], axis=1)

    # Concatenate transposed columns with non-transposed columns
    result_df = pd.concat([df[list_not_transpose], transposed_df], axis=1)
    
    result_df=result_df.iloc[:1]
    #display(result_df)
    
    wound_columns = [col for col in result_df.columns if col.startswith('Wound_healing_status_Visit')]

    # Extract the column with the highest number after "Visit"
    max_visit_number = max(int(col.split('Visit')[1]) for col in wound_columns)
    max_visit_column = f'Wound_healing_status_Visit{max_visit_number}'
    print("\n",max_visit_column)
    # Extract the values from the selected column
    result_df['FinalVisit_Healing_Status'] = result_df[max_visit_column]
    
    # Specify the columns to be moved to the front
    columns_to_front = ['PatientIDWoundNumber', 'FinalVisit_Healing_Status']

    # Move the specified columns to the front
    result_df = pd.concat([result_df[columns_to_front], result_df.drop(columns=columns_to_front)], axis=1)

    #display(result_df)
    
    transposed_big_df=pd.concat([transposed_big_df, result_df], axis=0)

# %%
transposed_big_df
# Out:
#         PatientIDWoundNumber  FinalVisit_Healing_Status  AccidentType  \
# 0                          0                        0.0             0
# 10                         1                        4.0             4
# 11                         2                        3.0             0
# 16                         3                        3.0             0
# 19                         4                        0.0             0
# ...                      ...                        ...           ...
# 197442                 24432                        1.0             0
# 197444                 24433                        3.0             0
# 197446                 24434                        3.0             0
# 197449                 24435                        0.0             0
# 197452                 24436                        0.0             0
#
#         Anterior_Posterior  Anterior_Dorsal  DateAcquired  DateInactive  \
# 0                        0                2           442          1574
# 10                       0                2           901          1574
# 11                       2                1          2461          1574
# 16                       2                1           457          1574
# 19                       2                2           917          1574
# ...                    ...              ...           ...           ...
# 197442                   2                2           264          1574
# 197444                   1                2           855          1574
# 197446                   0                2           250          1574
# 197449                   0                2           250          1574
# 197452                   2                2          1973          1574
#
#         DateOfAccident  DateWoundHealed  Inferior_Superior  ...  \
# 0                  568             1586                  2  ...
# 10                 568             1586                  2  ...
# 11                 568             1586                  2  ...
# 16                 568             1586                  1  ...
# 19                 568             1586                  2  ...
# ...                ...              ...                ...  ...
# 197442             568             1586                  2  ...
# 197444             568             1586                  2  ...
# 197446             568             1586                  2  ...
# 197449             568             1586                  2  ...
# 197452             568             1586                  2  ...
#
#         tunneling_Visit469  TunnelingOrUndermining_Visit469  Width_Visit469  \
# 0                      NaN                              NaN             NaN
# 10                     NaN                              NaN             NaN
# 11                     NaN                              NaN             NaN
# 16                     NaN                              NaN             NaN
# 19                     NaN                              NaN             NaN
# ...                    ...                              ...             ...
# 197442                 NaN                              NaN             NaN
# 197444                 NaN                              NaN             NaN
# 197446                 NaN                              NaN             NaN
# 197449                 NaN                              NaN             NaN
# 197452                 NaN                              NaN             NaN
#
#         woundProgress_Visit469  GranulationTexture_Visit469  \
# 0                          NaN                          NaN
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 16                         NaN                          NaN
# 19                         NaN                          NaN
# ...                        ...                          ...
# 197442                     NaN                          NaN
# 197444                     NaN                          NaN
# 197446                     NaN                          NaN
# 197449                     NaN                          NaN
# 197452                     NaN                          NaN
#
#         WoundMargin_Visit469  eschar_Visit469  Wound_healing_status_Visit469  \
# 0                        NaN              NaN                            NaN
# 10                       NaN              NaN                            NaN
# 11                       NaN              NaN                            NaN
# 16                       NaN              NaN                            NaN
# 19                       NaN              NaN                            NaN
# ...                      ...              ...                            ...
# 197442                   NaN              NaN                            NaN
# 197444                   NaN              NaN                            NaN
# 197446                   NaN              NaN                            NaN
# 197449                   NaN              NaN                            NaN
# 197452                   NaN              NaN                            NaN
#
#         Wound_healing_percentage_Visit469  DayNumber_Visit469
# 0                                     NaN                 NaN
# 10                                    NaN                 NaN
# 11                                    NaN                 NaN
# 16                                    NaN                 NaN
# 19                                    NaN                 NaN
# ...                                   ...                 ...
# 197442                                NaN                 NaN
# 197444                                NaN                 NaN
# 197446                                NaN                 NaN
# 197449                                NaN                 NaN
# 197452                                NaN                 NaN
#
# [24437 rows x 31004 columns]

# %%
transposed_big_df.to_csv("transposed_big_df.csv")

# %%
transposed_big_df["FinalVisit_Healing_Status"].value_counts()
# Out:
# FinalVisit_Healing_Status
# 3.0    8343
# 1.0    6037
# 4.0    4509
# 2.0    2967
# 0.0    2581
# Name: count, dtype: int64

# %%
# 3 = not healing
# 0 = grey
# 2 = healing
# 4 = unknown
# 1 = healed

# %% [markdown]
# ## Removing those columns which have more than 50% of total number of rows as null.

# %%
# Set the threshold for non-null values (50% of total rows)
threshold = 0.1 * len(transposed_big_df)

# Drop columns with less than the specified threshold
filtered_big_df = transposed_big_df.dropna(axis=1, thresh=threshold)

# Display the filtered DataFrame
filtered_big_df
# Out:
#         PatientIDWoundNumber  FinalVisit_Healing_Status  AccidentType  \
# 0                          0                        0.0             0
# 10                         1                        4.0             4
# 11                         2                        3.0             0
# 16                         3                        3.0             0
# 19                         4                        0.0             0
# ...                      ...                        ...           ...
# 197442                 24432                        1.0             0
# 197444                 24433                        3.0             0
# 197446                 24434                        3.0             0
# 197449                 24435                        0.0             0
# 197452                 24436                        0.0             0
#
#         Anterior_Posterior  Anterior_Dorsal  DateAcquired  DateInactive  \
# 0                        0                2           442          1574
# 10                       0                2           901          1574
# 11                       2                1          2461          1574
# 16                       2                1           457          1574
# 19                       2                2           917          1574
# ...                    ...              ...           ...           ...
# 197442                   2                2           264          1574
# 197444                   1                2           855          1574
# 197446                   0                2           250          1574
# 197449                   0                2           250          1574
# 197452                   2                2          1973          1574
#
#         DateOfAccident  DateWoundHealed  Inferior_Superior  ...  \
# 0                  568             1586                  2  ...
# 10                 568             1586                  2  ...
# 11                 568             1586                  2  ...
# 16                 568             1586                  1  ...
# 19                 568             1586                  2  ...
# ...                ...              ...                ...  ...
# 197442             568             1586                  2  ...
# 197444             568             1586                  2  ...
# 197446             568             1586                  2  ...
# 197449             568             1586                  2  ...
# 197452             568             1586                  2  ...
#
#         SystematicInfection_Visit18  TendonNecrosisExposed_Visit18  \
# 0                               NaN                            NaN
# 10                              NaN                            NaN
# 11                              NaN                            NaN
# 16                              NaN                            NaN
# 19                              NaN                            NaN
# ...                             ...                            ...
# 197442                          NaN                            NaN
# 197444                          NaN                            NaN
# 197446                          NaN                            NaN
# 197449                          NaN                            NaN
# 197452                          1.0                            1.0
#
#         TunnelingOrUndermining_Visit18  Width_Visit18  woundProgress_Visit18  \
# 0                                  NaN            NaN                    NaN
# 10                                 NaN            NaN                    NaN
# 11                                 NaN            NaN                    NaN
# 16                                 NaN            NaN                    NaN
# 19                                 NaN            NaN                    NaN
# ...                                ...            ...                    ...
# 197442                             NaN            NaN                    NaN
# 197444                             NaN            NaN                    NaN
# 197446                             NaN            NaN                    NaN
# 197449                             NaN            NaN                    NaN
# 197452                             1.0            9.0                    2.0
#
#         WoundMargin_Visit18  eschar_Visit18  Wound_healing_status_Visit18  \
# 0                       NaN             NaN                           NaN
# 10                      NaN             NaN                           NaN
# 11                      NaN             NaN                           NaN
# 16                      NaN             NaN                           NaN
# 19                      NaN             NaN                           NaN
# ...                     ...             ...                           ...
# 197442                  NaN             NaN                           NaN
# 197444                  NaN             NaN                           NaN
# 197446                  NaN             NaN                           NaN
# 197449                  NaN             NaN                           NaN
# 197452                  0.0            16.0                           3.0
#
#         Wound_healing_percentage_Visit18  DayNumber_Visit18
# 0                                    NaN                NaN
# 10                                   NaN                NaN
# 11                                   NaN                NaN
# 16                                   NaN                NaN
# 19                                   NaN                NaN
# ...                                  ...                ...
# 197442                               NaN                NaN
# 197444                               NaN                NaN
# 197446                               NaN                NaN
# 197449                               NaN                NaN
# 197452                               0.0               66.0
#
# [24437 rows x 1200 columns]

# %%
filtered_big_df.to_csv("filtered_big_df.csv")

# %%
# import pandas as pd

# # Your result DataFrame
# data = {'column1_1': [1, 2, 3, 4],
#         'column2_1': [4, 6, 7, 10],
#         'column1_2': [2, 3, 4, None],
#         'column2_2': [6, 7, 10, None],
#         'column1_3': [3, 4, None, None],
#         'column2_3': [7, 10, None, None],
#         'column1_4': [4, None, None, None],
#         'column2_4': [10, None, None, None],
#         'column3': [4, 4, 4, 4],
#         'column4': [9, 9, 9, 9]}

# result_df = pd.DataFrame(data)

# # Extract column_2 with the highest number as suffix
# max_suffix_column = result_df.filter(like='column2_').idxmax(axis=1)

# # Extract the corresponding values using the extracted column name
# result_df['max_suffix_column'] = result_df.apply(lambda row: row[max_suffix_column[row.name]] if pd.notna(row[max_suffix_column[row.name]]) else None, axis=1)

# # Display the result
# print(result_df)

# %%
# import csv
# file = open('FINAL_results2.csv', 'w', newline='')
# writer = csv.writer(file)

# # making header
# header = ['PatientIDWoundNumber']
# header.extend(list_not_transpose)

# for i in range(0, maximum):
#     for j in range(len(list_to_transpose)):
#         header.append("Visit" + str(i+1) + list_to_transpose[j])
           
# writer.writerow(header)

# %%
# print(big_df['PatientIDWoundNumber'].nunique())

# %%
# big_df['area'] = big_df['area'].replace(0,0.00001)
# patients = big_df['PatientIDWoundNumber']
# count = 0

# for i in patients.unique():
#     count = count + 1
#     #print(count)
# #     if count>10:
# #         break
#     new_row = [i] # adds patientIDWoundNumber 

#     # fetching entries for specific patient and wound number
#     entries = big_df[(big_df['PatientIDWoundNumber'] == i)]
    
#     if entries.empty:
#         continue
#     else:
#         entries = entries.reset_index()
#         entries = entries.drop(["index"], axis = 1)
        
#         # adding the data for the columns that are NOT being tranposed
#         new_row.append(entries.ActiveWound.get(len(entries) - 1))
#         new_row.append(entries.AdmissionDate.get(len(entries) - 1))
#         new_row.append(entries.AdmissionStatusCode.get(len(entries) - 1))
#         new_row.append(entries.Admission_dateAdded.get(len(entries) - 1))
#         new_row.append(entries.Age.get(len(entries) - 1))
#         new_row.append(entries.Anterior_Dorsal.get(len(entries) - 1))
#         new_row.append(entries.Anterior_Posterior.get(len(entries) - 1))
#         new_row.append(entries.Bleeding.get(len(entries) - 1))
#         new_row.append(entries.CauseOfDeath.get(len(entries) - 1))
#         new_row.append(entries.DateAcquired.get(len(entries) - 1))
#         new_row.append(entries.DateAdded_patient.get(len(entries) - 1))
#         new_row.append(entries.DateAdded_wound.get(len(entries) - 1))
#         new_row.append(entries.DateInactive.get(len(entries) - 1))
#         new_row.append(entries.DateOfAccident.get(len(entries) - 1))
#         new_row.append(entries.DateOfDeath.get(len(entries) - 1))
#         new_row.append(entries.DateWoundHealed.get(len(entries) - 1))
#         new_row.append(entries.DebridementLevel.get(len(entries) - 1))
#         new_row.append(entries.Inferior_Superior.get(len(entries) - 1))
#         new_row.append(entries.IsThisBurn.get(len(entries) - 1))
#         new_row.append(entries.Left_Right.get(len(entries) - 1))
#         new_row.append(entries.Location.get(len(entries) - 1))
#         new_row.append(entries.MedicareAdmission.get(len(entries) - 1))
#         new_row.append(entries.Method.get(len(entries) - 1))
#         new_row.append(entries.NonWoundDiagnosis.get(len(entries) - 1))
#         new_row.append(entries.Notes.get(len(entries) - 1))
#         new_row.append(entries.PInsuranceZip.get(len(entries) - 1))
#         new_row.append(entries.PalliativeCare.get(len(entries) - 1))
#         new_row.append(entries.PatientDOB.get(len(entries) - 1))
#         new_row.append(entries.PatientGender.get(len(entries) - 1))
#         new_row.append(entries.PatientSelfCare.get(len(entries) - 1))
#         new_row.append(entries.PatientZIP.get(len(entries) - 1))
#         new_row.append(entries.Patient_RiskLevel.get(len(entries) - 1))
#         new_row.append(entries.Patient_Score.get(len(entries) - 1))
#         new_row.append(entries.Patient_Title.get(len(entries) - 1))
#         new_row.append(entries.Proximal_Distal.get(len(entries) - 1))
#         new_row.append(entries.RaceCodeList.get(len(entries) - 1))
#         new_row.append(entries.Religion.get(len(entries) - 1))
#         new_row.append(entries.ResolvedRecurrence.get(len(entries) - 1))
#         new_row.append(entries.SInsuranceZip.get(len(entries) - 1))
#         new_row.append(entries.SmokingStatus.get(len(entries) - 1))
#         new_row.append(entries.SmokingStatusText.get(len(entries) - 1))
#         #new_row.append(entries.TInsuranceZip.get(len(entries) - 1))
#         new_row.append(entries.Type.get(len(entries) - 1))
#         new_row.append(entries.Weight.get(len(entries) - 1))
#         new_row.append(entries.WoundCondition.get(len(entries) - 1))
#         new_row.append(entries.firstAssessmentDate.get(len(entries) - 1))
#         new_row.append(entries.woundstatus.get(len(entries) - 1))

#         # adding data for transposed columns
#         for k in range(0, len(entries)):
#             new_row.append(entries.CompCompression.get(k))
#             new_row.append(entries.DayNumber.get(k))
#             new_row.append(entries.Depth.get(k))
#             new_row.append(entries.Epithialization.get(k))
#             new_row.append(entries.Exudate.get(k))
#             new_row.append(entries.ExudateAmount.get(k))
#             new_row.append(entries.GranulationTexture.get(k))
#             new_row.append(entries.NoMeasurableDepth.get(k))
#             new_row.append(entries.NormalColor.get(k))
#             new_row.append(entries.NormalMoisture.get(k))
#             new_row.append(entries.Odor.get(k))
#             new_row.append(entries.Pain.get(k))
#             new_row.append(entries.Pulse.get(k))
#             new_row.append(entries.RedGranulation.get(k))
#             new_row.append(entries.SSCAndSPending.get(k))
#             new_row.append(entries.SSConfirmedLocal.get(k))
#             new_row.append(entries.SSConfirmedSystemic.get(k))
#             new_row.append(entries.SSSignsAndSymptoms.get(k))
#             new_row.append(entries.SSSystemicAntibiotics.get(k))
#             new_row.append(entries.SSTopicalAntibiotics.get(k))
#             new_row.append(entries.SSXRay.get(k))
#             new_row.append(entries.SloughLessThan20.get(k))
#             new_row.append(entries.Stage.get(k))
#             new_row.append(entries.Temperature.get(k))
#             new_row.append(entries.TunnelingOrUndermining.get(k))
#             new_row.append(entries.Volume.get(k))
#             #new_row.append(entries.Wound_Title.get(k))
#             new_row.append(entries.WoundMargin.get(k))
#             new_row.append(entries.area.get(k))
#             if k != 0: # adding wound healing status column
#                 calc_area = (((entries.area.get(k - 1) - entries.area.get(k))/entries.area.get(k - 1))*100)
#                 if (calc_area == 100):
#                     new_row.append("healed")
#                 elif (calc_area >= 65):
#                     new_row.append("healing")
#                 elif ((calc_area < 65) & (calc_area >= 20)):
#                     new_row.append("gray area")
#                 else:
#                     new_row.append("not healing")
#             else:
#                 new_row.append("Unknown")
#             new_row.append(entries.color.get(k))
#             new_row.append(entries.eschar.get(k))
#             new_row.append(entries.imageFileCount.get(k))
#             new_row.append(entries.normalTexture.get(k))
#             new_row.append(entries.slough.get(k))
#             new_row.append(entries.surroundingSkin.get(k))
#             new_row.append(entries.surroundingSkinColor.get(k))
#             new_row.append(entries.tunneling.get(k))
#             new_row.append(entries.woundProgress.get(k))
        
#         # finally writing the info to the csv file
# #       print(new_row)
#         #print(i)
#         writer.writerow(new_row)

# %%
# dff = pd.read_csv("FINAL_results2.csv",low_memory=False)
# dff
